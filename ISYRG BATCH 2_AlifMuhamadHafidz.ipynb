# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import glob

# %%
data = 'C:/Users/Alif/ISYSRG/Dataset/image/jantung koroner.jpg'

# %%
gambar = cv2.imread(data)

# %%
plt.imshow(gambar)
