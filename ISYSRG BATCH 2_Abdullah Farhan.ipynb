# %%
import numpy as np
import wfdb
import matplotlib.pyplot as plt
import glob

# %%
path_data = 'C:/Users/Farhan/Documents/data/100'

# %%
sinyal = wfdb.rdrecord(path_data)

# %%
sinyal_doc = sinyal.__dict__

# %%
data = wfdb.rdann(path_data, 'atr')

# %%
data_doc = data.__dict__

# %%
psignal =sinyal_doc["p_signal"]

# %%
psignal_0 =psignal[:,0]

# %%
plt.plot(range(720),psignal_0[360:1080])

# %%
plt.plot(range(360),psignal_0[360:720])
