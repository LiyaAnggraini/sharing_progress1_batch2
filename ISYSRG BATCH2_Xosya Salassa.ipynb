# %%
import wfdb
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
stress = "E:/KULIAH/Semester 5/ISYSRG/noise stress/noise stress/118e_6"

# %%
stress
# Out:
# 'E:/KULIAH/Semester 5/ISYSRG/noise stress/noise stress/118e_6'

# %%
record = wfdb.rdrecord(stress)
dict_record = record.__dict__

# %%
sinyal = wfdb.rdrecord(stress)
sinyal_doc = sinyal.__dict__

# %%
data = wfdb.rdann(stress, 'atr')
data_doc = data.__dict__

# %%
psignal =sinyal_doc["p_signal"]
psignal_0 =psignal[:,0]

# %%
plt.plot(range(360),psignal_0[:360])
