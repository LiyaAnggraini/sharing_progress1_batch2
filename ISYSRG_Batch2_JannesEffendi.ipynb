# %%
import numpy as np
import wfdb
import matplotlib.pyplot as plt

# %%
path_data = 'C:/Users/Jannes/Downloads/Python AI/data/Dataset/100'
# banyak parameter
sinyal = wfdb.rdrecord(path_data)
sinyal_doc = sinyal.__dict__
data = wfdb.rdann(path_data, 'atr')
data_doc = data.__dict__

psignal =sinyal_doc["p_signal"]
psignal_0 =psignal[:,0]

sinyal_1Detik = psignal_0[0:360]

plt.plot(range(len(sinyal_1Detik)),sinyal_1Detik)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
